# %%
import pandas as pd
a=pd.read_csv(filepath)
a.head()
a.size
a.ndim
a.plot(x='name',y='dinner')

# %%
import pandas as pd
a= pd.read_csv('/content/BangaloreZomatoData.csv')
print(a)
a.head()
# a.size
# a.shape
# a.ndim
a.plot(x='Name',y='Dinner Reviews')
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                     URL  \
# 0     https://www.zomato.com/bangalore/sri-udupi-par...
# 1     https://www.zomato.com/bangalore/meghana-foods...
# 2     https://www.zomato.com/bangalore/donne-biriyan...
# 3     https://www.zomato.com/bangalore/dominos-pizza...
# 4      https://www.zomato.com/bangalore/kfc-indiranagar
# ...                                                 ...
# 8918  https://www.zomato.com/bangalore/new-sbfc-food...
# 8919  https://www.zomato.com/bangalore/kudla-coraltr...
# 8920  https://www.zomato.com/bangalore/bangkok-bowl-...
# ...

# %%
import pandas as pd
a= pd.read_csv('/content/BangaloreZomatoData.csv')
print(a)
a.head()
a.plot(x='Name',y=len('Cuisines'),kind='bar')
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                     URL  \
# 0     https://www.zomato.com/bangalore/sri-udupi-par...
# 1     https://www.zomato.com/bangalore/meghana-foods...
# 2     https://www.zomato.com/bangalore/donne-biriyan...
# 3     https://www.zomato.com/bangalore/dominos-pizza...
# 4      https://www.zomato.com/bangalore/kfc-indiranagar
# ...                                                 ...
# 8918  https://www.zomato.com/bangalore/new-sbfc-food...
# 8919  https://www.zomato.com/bangalore/kudla-coraltr...
# 8920  https://www.zomato.com/bangalore/bangkok-bowl-...
# ...

# %%
import pandas as pd
a= pd.read_csv('/content/BangaloreZomatoData.csv')
print(a)
a.head()
a.plot(x='Name',y=int(str('11:30pm')),kind='bar')
a= pd.to_datetime
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                     URL  \
# 0     https://www.zomato.com/bangalore/sri-udupi-par...
# 1     https://www.zomato.com/bangalore/meghana-foods...
# 2     https://www.zomato.com/bangalore/donne-biriyan...
# 3     https://www.zomato.com/bangalore/dominos-pizza...
# 4      https://www.zomato.com/bangalore/kfc-indiranagar
# ...                                                 ...
# 8918  https://www.zomato.com/bangalore/new-sbfc-food...
# 8919  https://www.zomato.com/bangalore/kudla-coraltr...
# 8920  https://www.zomato.com/bangalore/bangkok-bowl-...
# ...
