# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravTiwariTechAnalyst/GT/blob/master/Besant_MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array([10,20,30])
y= np.array([1,3,5])
plt.plot(x,y)
plt.bar(x,y)
plt.scatter(x,y)
plt.plot(y,marker="*",ms=20)

# %%
import matplotlib.pyplot as plt

import numpy as np
x=np.array([10,20,30])
y=np.array([1,2,3])
plt.plot(x,y)
plt.bar(x,y)
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array(["kgf","RRR"])
y= np.array([2000,1000])
#plt.plot(x,y)
#plt.bar(x,y)
#plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array(["kgf","RRR"])
y= np.array([2000,1000])
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
l= np.array(["kgf","RRR"])
y= np.array([2000,1000])
#plt.plot(x,y)
#plt.bar(x,y)
#plt.scatter(x,y)
plt.pie(y,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f84152590>,
# ...
#  [Text(-0.5500000594609755, 0.9526279098330699, 'kgf'),
#   Text(0.5500001486524352, -0.9526278583383436, 'RRR')])

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array(["kgf","RRR"])
y= np.array([2000,1000])
#plt.plot(x,y)
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([20000,25000,50000,60000,11000,7000,2000,8000])
y = np.array(["Rama","Ravi","Raju","Krishna","Navya","Shweta","Shruti","Akshay"])
plt.plot(x,y)
plt.plot(y, marker='*',ms=20)
# plt.xlabel="owner_name"
# plt.ylabel="Income"
# plt.title="Calculation"
# avg= sum(x)/len(x)
# print (avg)
# c= zip(x,y)
# for x in c:
#   print(x)
# print (x[-1])
# print (c[-1])
